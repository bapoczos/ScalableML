# %%
import sys
import asyncio
from functools import partial
from aio_pika import connect, IncomingMessage,Exchange, Message, ExchangeType


import time

import numpy as np

from utils import NumpyEncoder

import json
import math
import socket
import os

# %%
async def on_message(exchange: Exchange, message: IncomingMessage):
    with message.process():
        print('** Request received **')
        
        print(" [x] %r:%r" % (
            message.routing_key,
            message.body
        ))

        print('reply_to: '+message.reply_to)
        print('correlation_id:'+message.correlation_id)
        print('exchange:', exchange)

        tmpip= socket.gethostbyname(socket.gethostname())
        print('ip: '+tmpip)

        proc_id=str(os.getpid())
        print('process id:'+proc_id)

        curr_time=str(time.time())
        #print('current time:'+curr_time)

        myresponse={'request': message.body.decode(), 'orig_routing': message.routing_key, 'ip': tmpip, 'process_id':proc_id,'curr_time': curr_time }
        json_dump = json.dumps(myresponse, cls=NumpyEncoder)
        print(json_dump)
        
        # send the results and the request's correlation_id back to the server
        # Use the incoming message's routing_key as well
        await exchange.publish(
            Message(
                body=json_dump.encode(),
                correlation_id=message.correlation_id
            ),
            routing_key=message.reply_to
        )
        
        print('** Request Completed **')
        print('*************** \n')

# %%
async def main(loop):
    # Perform connection
    connection = await connect(
        "amqp://guest:guest@localhost/", loop=loop
    )

    # Creating a channel
    channel = await connection.channel()
    await channel.set_qos(prefetch_count=1)

    
     
    # Declare an exchange
    direct_logs_exchange = await channel.declare_exchange(
        'direct_logs', ExchangeType.DIRECT
    )

    # Declaring random queue
    queue = await channel.declare_queue(durable=True)

    #for myrouting in ['Pittsburgh','NYC']:
    for myrouting in ['Pittsburgh','Washington']:
        await queue.bind(direct_logs_exchange, routing_key=myrouting)
    
    # Start listening the queue for incoming messgaes
    # process the incoming message with the on_message callback function
    await queue.consume(
        partial(
            on_message,
            direct_logs_exchange
        )
    )

# %%
loop = asyncio.get_event_loop()
loop.create_task(main(loop))

# we enter a never-ending loop that waits for data
# and runs callbacks whenever necessary.
print(" [*] Waiting for messages. To exit press CTRL+C")
loop.run_forever()
# Out:
#  [*] Waiting for messages. To exit press CTRL+C
# ** Request received **
#  [x] 'Pittsburgh':b'Message1_Pittsburgh'
# reply_to: amq.gen-SBpZLysHGb9Z8kxHmFQepw
# correlation_id:70baf8dd-3b49-49fc-9e03-36154fcc8b18
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message1_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8018868"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Pittsburgh':b'Message3_Pittsburgh'
# reply_to: amq.gen-Bl4slSY6Itwog0r2UupMjQ
# correlation_id:ef2491a2-bcb7-4dc1-91ff-8dbbed4bfe59
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message3_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8318546"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Washington':b'Message5_Washington'
# reply_to: amq.gen-UrmbbCsIp9zYzfWqMuquXQ
# correlation_id:86b4d10b-4147-406a-aeeb-1a615b78e092
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message5_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8590782"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Pittsburgh':b'Message7_Pittsburgh'
# reply_to: amq.gen-8V_kiaHMiCqcfGXe6IxMGA
# correlation_id:8ab3a30f-0098-426f-9b03-f534406af221
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message7_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8884017"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Washington':b'Message8_Washington'
# reply_to: amq.gen-Ml4eFfGvnOgMwJ8lCFJOXA
# correlation_id:507f1886-9f6c-4784-a3a7-8b01ec4aa5d3
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message8_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9033797"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Washington':b'Message9_Washington'
# reply_to: amq.gen-ioipGmhMqub7Nyq56-_IMg
# correlation_id:4a01a933-db01-448d-9981-203c3240ff46
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message9_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9153275"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Pittsburgh':b'Message10_Pittsburgh'
# reply_to: amq.gen-5a65MLJw9LI794Hv8KNUbw
# correlation_id:5b5d04d0-86cf-4a4a-bedb-d3378996b630
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message10_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9290466"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Pittsburgh':b'Message11_Pittsburgh'
# reply_to: amq.gen-HQynAANjgf90kJgt83Toqw
# correlation_id:6c3d83cb-a55e-4a22-8c6c-f5786103ac63
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message11_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9487085"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Washington':b'Message13_Washington'
# reply_to: amq.gen-YxdjNYPhI7javjrfVEb-YQ
# correlation_id:856855a6-f02f-454c-aea4-cd1be2b3dc16
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message13_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9771109"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Washington':b'Message14_Washington'
# reply_to: amq.gen-jWj-Xd06BI9xKZ3QFw-2iw
# correlation_id:47ce8a9c-3521-447e-87cc-e53fb623f3ef
# exchange: direct_logs
# ip: 172.31.29.180
# process id:12882
# {"request": "Message14_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9916677"}
# ** Request Completed **
# ***************
