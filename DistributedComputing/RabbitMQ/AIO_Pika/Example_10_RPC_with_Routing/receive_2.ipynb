# %%
import sys
import asyncio
from functools import partial
from aio_pika import connect, IncomingMessage,Exchange, Message, ExchangeType


import time

import numpy as np

from utils import NumpyEncoder

import json
import math
import socket
import os

# %%
async def on_message(exchange: Exchange, message: IncomingMessage):
    with message.process():
        print('** Request received **')
        
        print(" [x] %r:%r" % (
            message.routing_key,
            message.body
        ))

        print('reply_to: '+message.reply_to)
        print('correlation_id:'+message.correlation_id)
        print('exchange:', exchange)

        tmpip= socket.gethostbyname(socket.gethostname())
        print('ip: '+tmpip)

        proc_id=str(os.getpid())
        print('process id:'+proc_id)

        curr_time=str(time.time())
        #print('current time:'+curr_time)

        myresponse={'request': message.body.decode(), 'orig_routing': message.routing_key, 'ip': tmpip, 'process_id':proc_id,'curr_time': curr_time }
        json_dump = json.dumps(myresponse, cls=NumpyEncoder)
        print(json_dump)
        
        # send the results and the request's correlation_id back to the server
        # Use the incoming message's routing_key as well
        await exchange.publish(
            Message(
                body=json_dump.encode(),
                correlation_id=message.correlation_id
            ),
            routing_key=message.reply_to
        )
        
        print('** Request Completed **')
        print('*************** \n')

# %%
async def main(loop):
    # Perform connection
    connection = await connect(
        "amqp://guest:guest@localhost/", loop=loop
    )

    # Creating a channel
    channel = await connection.channel()
    await channel.set_qos(prefetch_count=1)

    
     
    # Declare an exchange
    direct_logs_exchange = await channel.declare_exchange(
        'direct_logs', ExchangeType.DIRECT
    )

    # Declaring random queue
    queue = await channel.declare_queue(durable=True)

    #for myrouting in ['Pittsburgh','NYC']:
    for myrouting in ['Pittsburgh','Washington']:
        await queue.bind(direct_logs_exchange, routing_key=myrouting)
    
    # Start listening the queue for incoming messgaes
    # process the incoming message with the on_message callback function
    await queue.consume(
        partial(
            on_message,
            direct_logs_exchange
        )
    )

# %%
loop = asyncio.get_event_loop()
loop.create_task(main(loop))

# we enter a never-ending loop that waits for data
# and runs callbacks whenever necessary.
print(" [*] Waiting for messages. To exit press CTRL+C")
loop.run_forever()
# Out:
#  [*] Waiting for messages. To exit press CTRL+C
# ** Request received **
#  [x] 'Washington':b'Message2_Washington'
# reply_to: amq.gen-WSFliHZdhVM8_kFSj-oShQ
# correlation_id:5f32d6ca-68e5-46cc-adb3-fbe1fa5a61ec
# exchange: direct_logs
# ip: 172.31.21.156
# process id:17990
# {"request": "Message2_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.4231875"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Washington':b'Message3_Washington'
# reply_to: amq.gen--a8Wqs1MiKoaRkmEt_Twsw
# correlation_id:6a17fc7c-8d20-42a8-9ec0-0db03bdc77b8
# exchange: direct_logs
# ip: 172.31.21.156
# process id:17990
# {"request": "Message3_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.4333844"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Washington':b'Message6_Washington'
# reply_to: amq.gen--P6-QoT7CjBxH9t9XpeBtQ
# correlation_id:1048c519-1c53-4662-987a-ced16c30ceae
# exchange: direct_logs
# ip: 172.31.21.156
# process id:17990
# {"request": "Message6_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.4779766"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Washington':b'Message8_Washington'
# reply_to: amq.gen-QKJIBPJtIlUt4400cjCyKw
# correlation_id:9680226e-15ce-49a2-b71f-dfba9a8b49d0
# exchange: direct_logs
# ip: 172.31.21.156
# process id:17990
# {"request": "Message8_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5062752"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Pittsburgh':b'Message9_Pittsburgh'
# reply_to: amq.gen-FoCr5CPxkjm7qp6tDGJZiw
# correlation_id:c8630d41-bbd6-4833-a7fa-85d64a4e9e87
# exchange: direct_logs
# ip: 172.31.21.156
# process id:17990
# {"request": "Message9_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5168924"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Washington':b'Message10_Washington'
# reply_to: amq.gen-DAS6llhFF4X50xbvNrT4bg
# correlation_id:d8011759-da52-4f5e-92a3-b8f8a5b71219
# exchange: direct_logs
# ip: 172.31.21.156
# process id:17990
# {"request": "Message10_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5286748"}
# ** Request Completed **
# ***************
#
# ** Request received **
#  [x] 'Pittsburgh':b'Message14_Pittsburgh'
# reply_to: amq.gen-bsmrXrn0R6-LZXSr02cySw
# correlation_id:12db10b0-0c79-4a2e-a558-6f32502fd430
# exchange: direct_logs
# ip: 172.31.21.156
# process id:17990
# {"request": "Message14_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5758743"}
# ** Request Completed **
# ***************
