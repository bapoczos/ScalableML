# %%
import sys
import asyncio
from aio_pika import connect,IncomingMessage, Message, DeliveryMode, Exchange, ExchangeType
import numpy as np
import uuid
import json

# %%
class RpcClient:
    def __init__(self, loop):
        
        self.connection = None #This will be filled-up later
        self.channel = None #This will be filled-up later
        self.callback_queue = None #This will be filled-up later
        
        # This is a dictionary. 
        # The key will be a correlation_id that we create when we call a worker machine.
        # The value will be an asyncio.Future object.
        self.futures = {}
        
        self.loop = loop # This will contain an event loop
        
        self.num_on_response_calls = 0 #We will count how many times workers responded to us
        self.num_of_workers = 2 # We want two workers to respond to messages with 'Pittsburgh' routing
        
    async def connect(self):
        
        # Create a connection
        self.connection = await connect(
            "amqp://guest:guest@localhost/", loop=loop
        )
        
        # Create a channel
        self.channel = await self.connection.channel()
        
        # Create an exchange with type direct
        self.exchange = await self.channel.declare_exchange('direct_logs', ExchangeType.DIRECT)

        # Create a queue with random name "self.callback_queue" for receving messages from the workers
        self.callback_queue = await self.channel.declare_queue(exclusive=True)
                
                
        # Start consuming messages on the "self.callback_queue" queue
        # Call the self.on_response callback function when we receive a message from the workers
        await self.callback_queue.consume(self.on_response)
        
        return self
    
    # We will run this callback function when we recevie messages from the workers
    def on_response(self, message: IncomingMessage):
        
        print('\n ---- SERVER ON_RESPONSE STARTS ----')
        print('message arrived back from worker: ' + str(message.body))
        print('correlation id of the incoming message: '+message.correlation_id)        
        
        self.num_on_response_calls = self.num_on_response_calls+1
        
        json_loads=json.loads(str(message.body.decode()))       
        orig_routing =  json_loads["orig_routing"] 
        print('orig_routing', orig_routing)
         
        if self.num_on_response_calls == self.num_of_workers:
            print('** All messages we needed arrived **')
            future = self.futures.pop(message.correlation_id)
            future.set_result(message.body)
            print(f'future object is done: {future}')
            
        elif orig_routing !='Pittsburgh':
            future = self.futures.pop(message.correlation_id)
            future.set_result(message.body)
            print(f'future object is done: {future}')
            
        print('---- SERVER ON_RESPONSE ENDS ---- \n')

   
    async def call(self,myiter):
        correlation_id = str(uuid.uuid4())
        
        #Create an asyncio.Future object attached to the event loop.
        #This future object will contain the result received from the worker
        future = loop.create_future()

        # Add new key-value pairs to the self.futures dictionary
        self.futures[correlation_id] = future

        index=np.random.randint(0,3)
        routing_list=['Pittsburgh','NYC','Washington']
        myrouting=routing_list[index]
        #myrouting='Pittsburgh'
        
        message_body = "Message"+str(myiter)+"_"+myrouting
        print(myrouting)
        
        # Below we send a message to the workers.
        # We also send the correlation_id of the message,
        # and the name of the callback_queue 
        # where we expect to recevie the answer from the workers received who received our message
        
        await self.exchange.publish(
                Message(
                    message_body.encode(),
                    content_type='text/plain',
                    correlation_id=correlation_id,
                    reply_to=self.callback_queue.name,
                    #delivery_mode=DeliveryMode.PERSISTENT
                ),
                routing_key=myrouting,
            )
        
        # bind the callback_queue with its routing_key to the exchange
        await self.callback_queue.bind(self.exchange, routing_key=self.callback_queue.name)
        
        print('************')
        
        
        return str(await future)

# %%
async def main_func(myiter,loop):
    my_rpc = await RpcClient(loop).connect()
    response = await my_rpc.call(myiter)
    print(" [.] Got:" +response)
    print("**** \n")

# %%
#loop = asyncio.get_event_loop()
#loop.run_until_complete(main_func(loop))

# %%
for myiter in range(15):
    loop = asyncio.get_event_loop()
    loop.run_until_complete(main_func(myiter,loop))
# Out:
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message0_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.3896747"}'
# correlation id of the incoming message: a2052906-85c3-4db9-a97e-bd50726a4e7b
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...633.3896747"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message0_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.3896747"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message1_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.4109952"}'
# correlation id of the incoming message: b2aa8c41-ddf1-40bc-81c8-8dc11cf6979e
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...633.4109952"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message1_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.4109952"}'
# ****
#
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message2_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.4231875"}'
# correlation id of the incoming message: 5f32d6ca-68e5-46cc-adb3-fbe1fa5a61ec
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...633.4231875"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message2_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.4231875"}'
# ****
#
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message3_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.4333844"}'
# correlation id of the incoming message: 6a17fc7c-8d20-42a8-9ec0-0db03bdc77b8
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...633.4333844"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message3_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.4333844"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message4_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.4432263"}'
# correlation id of the incoming message: 683d19c3-862e-4d94-a61e-b961a27a1a6f
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...633.4432263"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message4_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.4432263"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message5_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.463563"}'
# correlation id of the incoming message: 3b24202f-54e4-4876-85c4-22baada81508
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...0633.463563"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message5_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.463563"}'
# ****
#
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message6_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.4779766"}'
# correlation id of the incoming message: 1048c519-1c53-4662-987a-ced16c30ceae
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...633.4779766"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message6_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.4779766"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message7_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.4926624"}'
# correlation id of the incoming message: 2956f438-989d-4c81-b4d7-753b1bc93730
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...633.4926624"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message7_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.4926624"}'
# ****
#
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message8_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5062752"}'
# correlation id of the incoming message: 9680226e-15ce-49a2-b71f-dfba9a8b49d0
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...633.5062752"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message8_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5062752"}'
# ****
#
# Pittsburgh
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message9_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5168924"}'
# correlation id of the incoming message: c8630d41-bbd6-4833-a7fa-85d64a4e9e87
# orig_routing Pittsburgh
# ---- SERVER ON_RESPONSE ENDS ----
#
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message9_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.516654"}'
# correlation id of the incoming message: c8630d41-bbd6-4833-a7fa-85d64a4e9e87
# orig_routing Pittsburgh
# ** All messages we needed arrived **
# future object is done: <Future finished result=b'{"request":...0633.516654"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message9_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.516654"}'
# ****
#
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message10_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5286748"}'
# correlation id of the incoming message: d8011759-da52-4f5e-92a3-b8f8a5b71219
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...633.5286748"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message10_Washington", "orig_routing": "Washington", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5286748"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message11_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.5396085"}'
# correlation id of the incoming message: b943e0a1-4a25-407e-86ed-5eaff662e69e
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...633.5396085"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message11_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.5396085"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message12_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.5541031"}'
# correlation id of the incoming message: e1f3e3e6-9a32-47c7-9899-62aaba5ab4a4
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...633.5541031"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message12_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.5541031"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message13_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.5648842"}'
# correlation id of the incoming message: 2f4cc4a6-9853-4ce4-9b84-985807cdf94a
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...633.5648842"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message13_NYC", "orig_routing": "NYC", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.5648842"}'
# ****
#
# Pittsburgh
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message14_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.21.156", "process_id": "17990", "curr_time": "1643480633.5758743"}'
# correlation id of the incoming message: 12db10b0-0c79-4a2e-a558-6f32502fd430
# orig_routing Pittsburgh
# ---- SERVER ON_RESPONSE ENDS ----
#
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message14_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.57621"}'
# correlation id of the incoming message: 12db10b0-0c79-4a2e-a558-6f32502fd430
# orig_routing Pittsburgh
# ** All messages we needed arrived **
# future object is done: <Future finished result=b'{"request":...80633.57621"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message14_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.21.156", "process_id": "18443", "curr_time": "1643480633.57621"}'
# ****

# %%
# Let's reset the rabbitmq
# !sudo rabbitmqctl stop_app
# !sudo rabbitmqctl reset
# !sudo rabbitmqctl start_app
# Out:
# Stopping node 'rabbit@ip-172-31-29-180' ...
# Resetting node 'rabbit@ip-172-31-29-180' ...
# Starting node 'rabbit@ip-172-31-29-180' ...

# %%
# !sudo rabbitmqctl list_bindings
# Out:
# Listing bindings ...
# 	exchange	amq.gen-5a65MLJw9LI794Hv8KNUbw	queue	amq.gen-5a65MLJw9LI794Hv8KNUbw	[]
# 	exchange	amq.gen-8V_kiaHMiCqcfGXe6IxMGA	queue	amq.gen-8V_kiaHMiCqcfGXe6IxMGA	[]
# 	exchange	amq.gen-Bl4slSY6Itwog0r2UupMjQ	queue	amq.gen-Bl4slSY6Itwog0r2UupMjQ	[]
# 	exchange	amq.gen-CF1rFzZujVLj-EVfAemHHA	queue	amq.gen-CF1rFzZujVLj-EVfAemHHA	[]
# 	exchange	amq.gen-HQynAANjgf90kJgt83Toqw	queue	amq.gen-HQynAANjgf90kJgt83Toqw	[]
# 	exchange	amq.gen-Ml4eFfGvnOgMwJ8lCFJOXA	queue	amq.gen-Ml4eFfGvnOgMwJ8lCFJOXA	[]
# 	exchange	amq.gen-SBpZLysHGb9Z8kxHmFQepw	queue	amq.gen-SBpZLysHGb9Z8kxHmFQepw	[]
# 	exchange	amq.gen-TRCrj0AUnKGdwuKKD8Xhmg	queue	amq.gen-TRCrj0AUnKGdwuKKD8Xhmg	[]
# 	exchange	amq.gen-UrmbbCsIp9zYzfWqMuquXQ	queue	amq.gen-UrmbbCsIp9zYzfWqMuquXQ	[]
# 	exchange	amq.gen-YxdjNYPhI7javjrfVEb-YQ	queue	amq.gen-YxdjNYPhI7javjrfVEb-YQ	[]
# 	exchange	amq.gen-_8geWvqaFjb8oUEC6-bYyw	queue	amq.gen-_8geWvqaFjb8oUEC6-bYyw	[]
# 	exchange	amq.gen-ioipGmhMqub7Nyq56-_IMg	queue	amq.gen-ioipGmhMqub7Nyq56-_IMg	[]
# 	exchange	amq.gen-jWj-Xd06BI9xKZ3QFw-2iw	queue	amq.gen-jWj-Xd06BI9xKZ3QFw-2iw	[]
# 	exchange	amq.gen-nNj8FtMLs6d_XV839brdaQ	queue	amq.gen-nNj8FtMLs6d_XV839brdaQ	[]
# 	exchange	amq.gen-nd60PkJy8_USLxiiIPz5-w	queue	amq.gen-nd60PkJy8_USLxiiIPz5-w	[]
# 	exchange	amq.gen-q_6zj5Esq-uL3LFhtLQsig	queue	amq.gen-q_6zj5Esq-uL3LFhtLQsig	[]
# 	exchange	amq.gen-xJlUE7B5ipRBxHoBUNMSNA	queue	amq.gen-xJlUE7B5ipRBxHoBUNMSNA	[]
# direct_logs	exchange	amq.gen-5a65MLJw9LI794Hv8KNUbw	queue	amq.gen-5a65MLJw9LI794Hv8KNUbw	[]
# direct_logs	exchange	amq.gen-8V_kiaHMiCqcfGXe6IxMGA	queue	amq.gen-8V_kiaHMiCqcfGXe6IxMGA	[]
# direct_logs	exchange	amq.gen-Bl4slSY6Itwog0r2UupMjQ	queue	amq.gen-Bl4slSY6Itwog0r2UupMjQ	[]
# direct_logs	exchange	amq.gen-CF1rFzZujVLj-EVfAemHHA	queue	amq.gen-CF1rFzZujVLj-EVfAemHHA	[]
# direct_logs	exchange	amq.gen-HQynAANjgf90kJgt83Toqw	queue	amq.gen-HQynAANjgf90kJgt83Toqw	[]
# direct_logs	exchange	amq.gen-Ml4eFfGvnOgMwJ8lCFJOXA	queue	amq.gen-Ml4eFfGvnOgMwJ8lCFJOXA	[]
# direct_logs	exchange	amq.gen-SBpZLysHGb9Z8kxHmFQepw	queue	amq.gen-SBpZLysHGb9Z8kxHmFQepw	[]
# direct_logs	exchange	amq.gen-TRCrj0AUnKGdwuKKD8Xhmg	queue	amq.gen-TRCrj0AUnKGdwuKKD8Xhmg	[]
# direct_logs	exchange	amq.gen-UrmbbCsIp9zYzfWqMuquXQ	queue	amq.gen-UrmbbCsIp9zYzfWqMuquXQ	[]
# direct_logs	exchange	amq.gen-YxdjNYPhI7javjrfVEb-YQ	queue	amq.gen-YxdjNYPhI7javjrfVEb-YQ	[]
# direct_logs	exchange	amq.gen-_8geWvqaFjb8oUEC6-bYyw	queue	amq.gen-_8geWvqaFjb8oUEC6-bYyw	[]
# direct_logs	exchange	amq.gen-ioipGmhMqub7Nyq56-_IMg	queue	amq.gen-ioipGmhMqub7Nyq56-_IMg	[]
# direct_logs	exchange	amq.gen-jWj-Xd06BI9xKZ3QFw-2iw	queue	amq.gen-jWj-Xd06BI9xKZ3QFw-2iw	[]
# direct_logs	exchange	amq.gen-nNj8FtMLs6d_XV839brdaQ	queue	amq.gen-nNj8FtMLs6d_XV839brdaQ	[]
# direct_logs	exchange	amq.gen-nd60PkJy8_USLxiiIPz5-w	queue	Pittsburgh	[]
# direct_logs	exchange	amq.gen-nd60PkJy8_USLxiiIPz5-w	queue	Washington	[]
# direct_logs	exchange	amq.gen-q_6zj5Esq-uL3LFhtLQsig	queue	NYC	[]
# direct_logs	exchange	amq.gen-q_6zj5Esq-uL3LFhtLQsig	queue	Pittsburgh	[]
# direct_logs	exchange	amq.gen-xJlUE7B5ipRBxHoBUNMSNA	queue	amq.gen-xJlUE7B5ipRBxHoBUNMSNA	[]
