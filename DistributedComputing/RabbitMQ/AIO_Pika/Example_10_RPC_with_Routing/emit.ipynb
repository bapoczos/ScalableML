# %%
import sys
import asyncio
from aio_pika import connect,IncomingMessage, Message, DeliveryMode, Exchange, ExchangeType
import numpy as np
import uuid
import json

# %%
class RpcClient:
    def __init__(self, loop):
        
        self.connection = None #This will be filled-up later
        self.channel = None #This will be filled-up later
        self.callback_queue = None #This will be filled-up later
        
        # This is a dictionary. 
        # The key will be a correlation_id that we create when we call a worker machine.
        # The value will be an asyncio.Future object.
        self.futures = {}
        
        self.loop = loop # This will contain an event loop
        
        self.num_on_response_calls = 0 #We will count how many times workers responded to us
        self.num_of_workers = 2 # We want two workers to respond to messages with 'Pittsburgh' routing
        
    async def connect(self):
        
        # Create a connection
        self.connection = await connect(
            "amqp://guest:guest@localhost/", loop=loop
        )
        
        # Create a channel
        self.channel = await self.connection.channel()
        
        # Create an exchange with type direct
        self.exchange = await self.channel.declare_exchange('direct_logs', ExchangeType.DIRECT)

        # Create a queue with random name "self.callback_queue" for receving messages from the workers
        self.callback_queue = await self.channel.declare_queue(exclusive=True)
                
                
        # Start consuming messages on the "self.callback_queue" queue
        # Call the self.on_response callback function when we receive a message from the workers
        await self.callback_queue.consume(self.on_response)
        
        return self
    
    # We will run this callback function when we recevie messages from the workers
    def on_response(self, message: IncomingMessage):
        
        print('\n ---- SERVER ON_RESPONSE STARTS ----')
        print('message arrived back from worker: ' + str(message.body))
        print('correlation id of the incoming message: '+message.correlation_id)        
        
        self.num_on_response_calls = self.num_on_response_calls+1
        
        json_loads=json.loads(str(message.body.decode()))       
        orig_routing =  json_loads["orig_routing"] 
        print('orig_routing', orig_routing)
         
        if self.num_on_response_calls == self.num_of_workers:
            print('** All messages we needed arrived **')
            future = self.futures.pop(message.correlation_id)
            future.set_result(message.body)
            print(f'future object is done: {future}')
            
        elif orig_routing !='Pittsburgh':
            future = self.futures.pop(message.correlation_id)
            future.set_result(message.body)
            print(f'future object is done: {future}')
            
        print('---- SERVER ON_RESPONSE ENDS ---- \n')

   
    async def call(self,myiter):
        correlation_id = str(uuid.uuid4())
        
        #Create an asyncio.Future object attached to the event loop.
        #This future object will contain the result received from the worker
        future = loop.create_future()

        # Add new key-value pairs to the self.futures dictionary
        self.futures[correlation_id] = future

        index=np.random.randint(0,3)
        routing_list=['Pittsburgh','NYC','Washington']
        myrouting=routing_list[index]
        #myrouting='Pittsburgh'
        
        message_body = "Message"+str(myiter)+"_"+myrouting
        print(myrouting)
        
        # Below we send a message to the workers.
        # We also send the correlation_id of the message,
        # and the name of the callback_queue 
        # where we expect to recevie the answer from the workers received who received our message
        
        await self.exchange.publish(
                Message(
                    message_body.encode(),
                    content_type='text/plain',
                    correlation_id=correlation_id,
                    reply_to=self.callback_queue.name,
                    #delivery_mode=DeliveryMode.PERSISTENT
                ),
                routing_key=myrouting,
            )
        
        # bind the callback_queue with its routing_key to the exchange
        await self.callback_queue.bind(self.exchange, routing_key=self.callback_queue.name)
        
        print('************')
        
        
        return str(await future)

# %%
async def main_func(myiter,loop):
    my_rpc = await RpcClient(loop).connect()
    response = await my_rpc.call(myiter)
    print(" [.] Got:" +response)
    print("**** \n")

# %%
#loop = asyncio.get_event_loop()
#loop.run_until_complete(main_func(loop))

# %%
for myiter in range(15):
    loop = asyncio.get_event_loop()
    loop.run_until_complete(main_func(myiter,loop))
# Out:
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message0_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.7867165"}'
# correlation id of the incoming message: 41c5a5e1-4819-40b4-9138-346c3ad4470b
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...100.7867165"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message0_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.7867165"}'
# ****
#
# Pittsburgh
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message1_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.7995646"}'
# correlation id of the incoming message: 70baf8dd-3b49-49fc-9e03-36154fcc8b18
# orig_routing Pittsburgh
# ---- SERVER ON_RESPONSE ENDS ----
#
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message1_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8018868"}'
# correlation id of the incoming message: 70baf8dd-3b49-49fc-9e03-36154fcc8b18
# orig_routing Pittsburgh
# ** All messages we needed arrived **
# future object is done: <Future finished result=b'{"request":...100.8018868"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message1_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8018868"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message2_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.818148"}'
# correlation id of the incoming message: ab24f542-2bab-415d-8d74-e08e1c6e2dc3
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...9100.818148"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message2_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.818148"}'
# ****
#
# Pittsburgh
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message3_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8318546"}'
# correlation id of the incoming message: ef2491a2-bcb7-4dc1-91ff-8dbbed4bfe59
# orig_routing Pittsburgh
# ---- SERVER ON_RESPONSE ENDS ----
#
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message3_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.8326125"}'
# correlation id of the incoming message: ef2491a2-bcb7-4dc1-91ff-8dbbed4bfe59
# orig_routing Pittsburgh
# ** All messages we needed arrived **
# future object is done: <Future finished result=b'{"request":...100.8326125"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message3_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.8326125"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message4_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.8456054"}'
# correlation id of the incoming message: e4e83fbf-c099-4c52-9c2a-230943d5eff7
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...100.8456054"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message4_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.8456054"}'
# ****
#
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message5_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8590782"}'
# correlation id of the incoming message: 86b4d10b-4147-406a-aeeb-1a615b78e092
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...100.8590782"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message5_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8590782"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message6_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.8732064"}'
# correlation id of the incoming message: cc8fa43f-002d-4712-b462-a117104a32d9
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...100.8732064"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message6_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.8732064"}'
# ****
#
# Pittsburgh
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message7_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.8884017"}'
# correlation id of the incoming message: 8ab3a30f-0098-426f-9b03-f534406af221
# orig_routing Pittsburgh
# ---- SERVER ON_RESPONSE ENDS ----
#
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message7_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.888426"}'
# correlation id of the incoming message: 8ab3a30f-0098-426f-9b03-f534406af221
# orig_routing Pittsburgh
# ** All messages we needed arrived **
# future object is done: <Future finished result=b'{"request":...9100.888426"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message7_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.888426"}'
# ****
#
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message8_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9033797"}'
# correlation id of the incoming message: 507f1886-9f6c-4784-a3a7-8b01ec4aa5d3
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...100.9033797"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message8_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9033797"}'
# ****
#
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message9_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9153275"}'
# correlation id of the incoming message: 4a01a933-db01-448d-9981-203c3240ff46
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...100.9153275"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message9_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9153275"}'
# ****
#
# Pittsburgh
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message10_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9290466"}'
# correlation id of the incoming message: 5b5d04d0-86cf-4a4a-bedb-d3378996b630
# orig_routing Pittsburgh
# ---- SERVER ON_RESPONSE ENDS ----
#
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message10_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.929212"}'
# correlation id of the incoming message: 5b5d04d0-86cf-4a4a-bedb-d3378996b630
# orig_routing Pittsburgh
# ** All messages we needed arrived **
# future object is done: <Future finished result=b'{"request":...9100.929212"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message10_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.929212"}'
# ****
#
# Pittsburgh
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message11_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.9486923"}'
# correlation id of the incoming message: 6c3d83cb-a55e-4a22-8c6c-f5786103ac63
# orig_routing Pittsburgh
# ---- SERVER ON_RESPONSE ENDS ----
#
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message11_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9487085"}'
# correlation id of the incoming message: 6c3d83cb-a55e-4a22-8c6c-f5786103ac63
# orig_routing Pittsburgh
# ** All messages we needed arrived **
# future object is done: <Future finished result=b'{"request":...100.9487085"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message11_Pittsburgh", "orig_routing": "Pittsburgh", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9487085"}'
# ****
#
# NYC
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message12_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.9636674"}'
# correlation id of the incoming message: 6cdbccee-9504-4bcd-929d-2b49d20b2687
# orig_routing NYC
# future object is done: <Future finished result=b'{"request":...100.9636674"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message12_NYC", "orig_routing": "NYC", "ip": "172.31.29.180", "process_id": "12521", "curr_time": "1643439100.9636674"}'
# ****
#
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message13_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9771109"}'
# correlation id of the incoming message: 856855a6-f02f-454c-aea4-cd1be2b3dc16
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...100.9771109"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message13_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9771109"}'
# ****
# Washington
# ************
#
#  ---- SERVER ON_RESPONSE STARTS ----
# message arrived back from worker: b'{"request": "Message14_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9916677"}'
# correlation id of the incoming message: 47ce8a9c-3521-447e-87cc-e53fb623f3ef
# orig_routing Washington
# future object is done: <Future finished result=b'{"request":...100.9916677"}'>
# ---- SERVER ON_RESPONSE ENDS ----
#
#  [.] Got:b'{"request": "Message14_Washington", "orig_routing": "Washington", "ip": "172.31.29.180", "process_id": "12882", "curr_time": "1643439100.9916677"}'
# ****

# %%
# Let's reset the rabbitmq
# !sudo rabbitmqctl stop_app
# !sudo rabbitmqctl reset
# !sudo rabbitmqctl start_app
# Out:
# Stopping node 'rabbit@ip-172-31-29-180' ...
# Resetting node 'rabbit@ip-172-31-29-180' ...
# Starting node 'rabbit@ip-172-31-29-180' ...

# %%
# !sudo rabbitmqctl list_bindings
# Out:
# Listing bindings ...
# 	exchange	amq.gen-5a65MLJw9LI794Hv8KNUbw	queue	amq.gen-5a65MLJw9LI794Hv8KNUbw	[]
# 	exchange	amq.gen-8V_kiaHMiCqcfGXe6IxMGA	queue	amq.gen-8V_kiaHMiCqcfGXe6IxMGA	[]
# 	exchange	amq.gen-Bl4slSY6Itwog0r2UupMjQ	queue	amq.gen-Bl4slSY6Itwog0r2UupMjQ	[]
# 	exchange	amq.gen-CF1rFzZujVLj-EVfAemHHA	queue	amq.gen-CF1rFzZujVLj-EVfAemHHA	[]
# 	exchange	amq.gen-HQynAANjgf90kJgt83Toqw	queue	amq.gen-HQynAANjgf90kJgt83Toqw	[]
# 	exchange	amq.gen-Ml4eFfGvnOgMwJ8lCFJOXA	queue	amq.gen-Ml4eFfGvnOgMwJ8lCFJOXA	[]
# 	exchange	amq.gen-SBpZLysHGb9Z8kxHmFQepw	queue	amq.gen-SBpZLysHGb9Z8kxHmFQepw	[]
# 	exchange	amq.gen-TRCrj0AUnKGdwuKKD8Xhmg	queue	amq.gen-TRCrj0AUnKGdwuKKD8Xhmg	[]
# 	exchange	amq.gen-UrmbbCsIp9zYzfWqMuquXQ	queue	amq.gen-UrmbbCsIp9zYzfWqMuquXQ	[]
# 	exchange	amq.gen-YxdjNYPhI7javjrfVEb-YQ	queue	amq.gen-YxdjNYPhI7javjrfVEb-YQ	[]
# 	exchange	amq.gen-_8geWvqaFjb8oUEC6-bYyw	queue	amq.gen-_8geWvqaFjb8oUEC6-bYyw	[]
# 	exchange	amq.gen-ioipGmhMqub7Nyq56-_IMg	queue	amq.gen-ioipGmhMqub7Nyq56-_IMg	[]
# 	exchange	amq.gen-jWj-Xd06BI9xKZ3QFw-2iw	queue	amq.gen-jWj-Xd06BI9xKZ3QFw-2iw	[]
# 	exchange	amq.gen-nNj8FtMLs6d_XV839brdaQ	queue	amq.gen-nNj8FtMLs6d_XV839brdaQ	[]
# 	exchange	amq.gen-nd60PkJy8_USLxiiIPz5-w	queue	amq.gen-nd60PkJy8_USLxiiIPz5-w	[]
# 	exchange	amq.gen-q_6zj5Esq-uL3LFhtLQsig	queue	amq.gen-q_6zj5Esq-uL3LFhtLQsig	[]
# 	exchange	amq.gen-xJlUE7B5ipRBxHoBUNMSNA	queue	amq.gen-xJlUE7B5ipRBxHoBUNMSNA	[]
# direct_logs	exchange	amq.gen-5a65MLJw9LI794Hv8KNUbw	queue	amq.gen-5a65MLJw9LI794Hv8KNUbw	[]
# direct_logs	exchange	amq.gen-8V_kiaHMiCqcfGXe6IxMGA	queue	amq.gen-8V_kiaHMiCqcfGXe6IxMGA	[]
# direct_logs	exchange	amq.gen-Bl4slSY6Itwog0r2UupMjQ	queue	amq.gen-Bl4slSY6Itwog0r2UupMjQ	[]
# direct_logs	exchange	amq.gen-CF1rFzZujVLj-EVfAemHHA	queue	amq.gen-CF1rFzZujVLj-EVfAemHHA	[]
# direct_logs	exchange	amq.gen-HQynAANjgf90kJgt83Toqw	queue	amq.gen-HQynAANjgf90kJgt83Toqw	[]
# direct_logs	exchange	amq.gen-Ml4eFfGvnOgMwJ8lCFJOXA	queue	amq.gen-Ml4eFfGvnOgMwJ8lCFJOXA	[]
# direct_logs	exchange	amq.gen-SBpZLysHGb9Z8kxHmFQepw	queue	amq.gen-SBpZLysHGb9Z8kxHmFQepw	[]
# direct_logs	exchange	amq.gen-TRCrj0AUnKGdwuKKD8Xhmg	queue	amq.gen-TRCrj0AUnKGdwuKKD8Xhmg	[]
# direct_logs	exchange	amq.gen-UrmbbCsIp9zYzfWqMuquXQ	queue	amq.gen-UrmbbCsIp9zYzfWqMuquXQ	[]
# direct_logs	exchange	amq.gen-YxdjNYPhI7javjrfVEb-YQ	queue	amq.gen-YxdjNYPhI7javjrfVEb-YQ	[]
# direct_logs	exchange	amq.gen-_8geWvqaFjb8oUEC6-bYyw	queue	amq.gen-_8geWvqaFjb8oUEC6-bYyw	[]
# direct_logs	exchange	amq.gen-ioipGmhMqub7Nyq56-_IMg	queue	amq.gen-ioipGmhMqub7Nyq56-_IMg	[]
# direct_logs	exchange	amq.gen-jWj-Xd06BI9xKZ3QFw-2iw	queue	amq.gen-jWj-Xd06BI9xKZ3QFw-2iw	[]
# direct_logs	exchange	amq.gen-nNj8FtMLs6d_XV839brdaQ	queue	amq.gen-nNj8FtMLs6d_XV839brdaQ	[]
# direct_logs	exchange	amq.gen-nd60PkJy8_USLxiiIPz5-w	queue	Pittsburgh	[]
# direct_logs	exchange	amq.gen-nd60PkJy8_USLxiiIPz5-w	queue	Washington	[]
# direct_logs	exchange	amq.gen-q_6zj5Esq-uL3LFhtLQsig	queue	NYC	[]
# direct_logs	exchange	amq.gen-q_6zj5Esq-uL3LFhtLQsig	queue	Pittsburgh	[]
# direct_logs	exchange	amq.gen-xJlUE7B5ipRBxHoBUNMSNA	queue	amq.gen-xJlUE7B5ipRBxHoBUNMSNA	[]
