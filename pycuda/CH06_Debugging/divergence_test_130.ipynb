# %%
# %%writefile divergence_test.cu
#
# #include <cuda_runtime.h>
# #include <stdio.h>
#
# __global__ void divergence_test_ker()
# {
# 	if( threadIdx.x % 2 == 0)
# 		printf("threadIdx.x %d : This is an even thread.\n", threadIdx.x);
# 	else
# 		printf("threadIdx.x %d : This is an odd thread.\n", threadIdx.x);
# }
#
# __host__ int main()
# {
# 	cudaSetDevice(0);
# 	divergence_test_ker<<<1, 32>>>();
# 	cudaDeviceSynchronize();
# 	cudaDeviceReset();
# }
# Out:
# Writing divergence_test.cu

# %% [markdown]
# Let's compile the program. We need to call nvcc with a shell command. In Jupyter, shell commands start with !. We need to include the directories for the Cuda include files (-I) and Cuda libraries (-L). Let's link also the cuBlas and cuSolver libraries, since you might need them at some point. We don't specify the name of the executable, so it will be the default a.out. If everything goes well, executing the cell does not give any output. If the compiler has problems, you will see the error messages:

# %%
# !nvcc -I /usr/local/cuda/samples/common/inc/ -L/usr/local/cuda/include -lcublas -lcusolver -arch=sm_35 -Wno-deprecated-gpu-targets divergence_test.cu

# %%
# !./a.out
# Out:
# threadIdx.x 1 : This is an odd thread.
# threadIdx.x 3 : This is an odd thread.
# threadIdx.x 5 : This is an odd thread.
# threadIdx.x 7 : This is an odd thread.
# threadIdx.x 9 : This is an odd thread.
# threadIdx.x 11 : This is an odd thread.
# threadIdx.x 13 : This is an odd thread.
# threadIdx.x 15 : This is an odd thread.
# threadIdx.x 17 : This is an odd thread.
# threadIdx.x 19 : This is an odd thread.
# threadIdx.x 21 : This is an odd thread.
# threadIdx.x 23 : This is an odd thread.
# threadIdx.x 25 : This is an odd thread.
# threadIdx.x 27 : This is an odd thread.
# threadIdx.x 29 : This is an odd thread.
# threadIdx.x 31 : This is an odd thread.
# threadIdx.x 0 : This is an even thread.
# threadIdx.x 2 : This is an even thread.
# threadIdx.x 4 : This is an even thread.
# threadIdx.x 6 : This is an even thread.
# threadIdx.x 8 : This is an even thread.
# threadIdx.x 10 : This is an even thread.
# threadIdx.x 12 : This is an even thread.
# threadIdx.x 14 : This is an even thread.
# threadIdx.x 16 : This is an even thread.
# threadIdx.x 18 : This is an even thread.
# threadIdx.x 20 : This is an even thread.
# threadIdx.x 22 : This is an even thread.
# threadIdx.x 24 : This is an even thread.
# threadIdx.x 26 : This is an even thread.
# threadIdx.x 28 : This is an even thread.
# threadIdx.x 30 : This is an even thread.

# %% [markdown]
# **The odd and even threads run in different orders!** <br> This happens because of the the warps' lockstep property. All the 32 threads in the warp must have run the same code.

# %%
 # %%writefile divergence_test2.cu

#include <cuda_runtime.h>
#include <stdio.h>

__global__ void divergence_test_ker()
{
	if( threadIdx.x % 3 == 0)
		printf("threadIdx.x %d : mod 0. \n", threadIdx.x);
	else if ( threadIdx.x % 3 == 1)
		printf("threadIdx.x %d : mod 1.\n", threadIdx.x);
  else
    printf("threadIdx.x %d : mod 2.\n", threadIdx.x);
}

__host__ int main()
{
	cudaSetDevice(0);
	divergence_test_ker<<<1, 300>>>();
	cudaDeviceSynchronize();
	cudaDeviceReset();
}
# Out:
# Overwriting divergence_test2.cu

# %%
# !nvcc -I /usr/local/cuda/samples/common/inc/ -L/usr/local/cuda/include -lcublas -lcusolver -arch=sm_35 -Wno-deprecated-gpu-targets divergence_test2.cu

# %%
# !./a.out
# Out:
# threadIdx.x 288 : mod 0.
# threadIdx.x 291 : mod 0.
# threadIdx.x 294 : mod 0.
# threadIdx.x 297 : mod 0.
# threadIdx.x 96 : mod 0.
# threadIdx.x 99 : mod 0.
# threadIdx.x 102 : mod 0.
# threadIdx.x 105 : mod 0.
# threadIdx.x 108 : mod 0.
# threadIdx.x 111 : mod 0.
# threadIdx.x 114 : mod 0.
# threadIdx.x 117 : mod 0.
# threadIdx.x 120 : mod 0.
# threadIdx.x 123 : mod 0.
# threadIdx.x 126 : mod 0.
# threadIdx.x 258 : mod 0.
# threadIdx.x 261 : mod 0.
# threadIdx.x 264 : mod 0.
# threadIdx.x 267 : mod 0.
# threadIdx.x 270 : mod 0.
# threadIdx.x 273 : mod 0.
# threadIdx.x 276 : mod 0.
# threadIdx.x 279 : mod 0.
# threadIdx.x 282 : mod 0.
# threadIdx.x 285 : mod 0.
# threadIdx.x 192 : mod 0.
# threadIdx.x 195 : mod 0.
# threadIdx.x 198 : mod 0.
# threadIdx.x 201 : mod 0.
# threadIdx.x 204 : mod 0.
# threadIdx.x 207 : mod 0.
# threadIdx.x 210 : mod 0.
# threadIdx.x 213 : mod 0.
# threadIdx.x 216 : mod 0.
# threadIdx.x 219 : mod 0.
# threadIdx.x 222 : mod 0.
# threadIdx.x 162 : mod 0.
# threadIdx.x 165 : mod 0.
# threadIdx.x 168 : mod 0.
# threadIdx.x 171 : mod 0.
# threadIdx.x 174 : mod 0.
# threadIdx.x 177 : mod 0.
# threadIdx.x 180 : mod 0.
# threadIdx.x 183 : mod 0.
# threadIdx.x 186 : mod 0.
# threadIdx.x 189 : mod 0.
# threadIdx.x 66 : mod 0.
# threadIdx.x 69 : mod 0.
# threadIdx.x 72 : mod 0.
# threadIdx.x 75 : mod 0.
# threadIdx.x 78 : mod 0.
# threadIdx.x 81 : mod 0.
# threadIdx.x 84 : mod 0.
# threadIdx.x 87 : mod 0.
# threadIdx.x 90 : mod 0.
# threadIdx.x 93 : mod 0.
# threadIdx.x 225 : mod 0.
# threadIdx.x 228 : mod 0.
# threadIdx.x 231 : mod 0.
# threadIdx.x 234 : mod 0.
# threadIdx.x 237 : mod 0.
# threadIdx.x 240 : mod 0.
# threadIdx.x 243 : mod 0.
# threadIdx.x 246 : mod 0.
# threadIdx.x 249 : mod 0.
# threadIdx.x 252 : mod 0.
# threadIdx.x 255 : mod 0.
# threadIdx.x 0 : mod 0.
# threadIdx.x 3 : mod 0.
# threadIdx.x 6 : mod 0.
# threadIdx.x 9 : mod 0.
# threadIdx.x 12 : mod 0.
# threadIdx.x 15 : mod 0.
# threadIdx.x 18 : mod 0.
# threadIdx.x 21 : mod 0.
# threadIdx.x 24 : mod 0.
# threadIdx.x 27 : mod 0.
# threadIdx.x 30 : mod 0.
# threadIdx.x 33 : mod 0.
# threadIdx.x 36 : mod 0.
# threadIdx.x 39 : mod 0.
# threadIdx.x 42 : mod 0.
# threadIdx.x 45 : mod 0.
# threadIdx.x 48 : mod 0.
# threadIdx.x 51 : mod 0.
# threadIdx.x 54 : mod 0.
# threadIdx.x 57 : mod 0.
# threadIdx.x 60 : mod 0.
# threadIdx.x 63 : mod 0.
# threadIdx.x 129 : mod 0.
# threadIdx.x 132 : mod 0.
# threadIdx.x 135 : mod 0.
# threadIdx.x 138 : mod 0.
# threadIdx.x 141 : mod 0.
# threadIdx.x 144 : mod 0.
# threadIdx.x 147 : mod 0.
# threadIdx.x 150 : mod 0.
# threadIdx.x 153 : mod 0.
# threadIdx.x 156 : mod 0.
# threadIdx.x 159 : mod 0.
# threadIdx.x 194 : mod 2.
# threadIdx.x 197 : mod 2.
# threadIdx.x 200 : mod 2.
# threadIdx.x 203 : mod 2.
# threadIdx.x 206 : mod 2.
# threadIdx.x 209 : mod 2.
# threadIdx.x 212 : mod 2.
# threadIdx.x 215 : mod 2.
# threadIdx.x 218 : mod 2.
# threadIdx.x 221 : mod 2.
# threadIdx.x 98 : mod 2.
# threadIdx.x 101 : mod 2.
# threadIdx.x 104 : mod 2.
# threadIdx.x 107 : mod 2.
# threadIdx.x 110 : mod 2.
# threadIdx.x 113 : mod 2.
# threadIdx.x 116 : mod 2.
# threadIdx.x 119 : mod 2.
# threadIdx.x 122 : mod 2.
# threadIdx.x 125 : mod 2.
# threadIdx.x 226 : mod 1.
# threadIdx.x 229 : mod 1.
# threadIdx.x 232 : mod 1.
# threadIdx.x 235 : mod 1.
# threadIdx.x 238 : mod 1.
# threadIdx.x 241 : mod 1.
# threadIdx.x 244 : mod 1.
# threadIdx.x 247 : mod 1.
# threadIdx.x 250 : mod 1.
# threadIdx.x 253 : mod 1.
# threadIdx.x 65 : mod 2.
# threadIdx.x 68 : mod 2.
# threadIdx.x 71 : mod 2.
# threadIdx.x 74 : mod 2.
# threadIdx.x 77 : mod 2.
# threadIdx.x 80 : mod 2.
# threadIdx.x 83 : mod 2.
# threadIdx.x 86 : mod 2.
# threadIdx.x 89 : mod 2.
# threadIdx.x 92 : mod 2.
# threadIdx.x 95 : mod 2.
# threadIdx.x 290 : mod 2.
# threadIdx.x 293 : mod 2.
# threadIdx.x 296 : mod 2.
# threadIdx.x 299 : mod 2.
# threadIdx.x 130 : mod 1.
# threadIdx.x 133 : mod 1.
# threadIdx.x 136 : mod 1.
# threadIdx.x 139 : mod 1.
# threadIdx.x 142 : mod 1.
# threadIdx.x 145 : mod 1.
# threadIdx.x 148 : mod 1.
# threadIdx.x 151 : mod 1.
# threadIdx.x 154 : mod 1.
# threadIdx.x 157 : mod 1.
# threadIdx.x 257 : mod 2.
# threadIdx.x 260 : mod 2.
# threadIdx.x 263 : mod 2.
# threadIdx.x 266 : mod 2.
# threadIdx.x 269 : mod 2.
# threadIdx.x 272 : mod 2.
# threadIdx.x 275 : mod 2.
# threadIdx.x 278 : mod 2.
# threadIdx.x 281 : mod 2.
# threadIdx.x 284 : mod 2.
# threadIdx.x 287 : mod 2.
# threadIdx.x 34 : mod 1.
# threadIdx.x 37 : mod 1.
# threadIdx.x 40 : mod 1.
# threadIdx.x 43 : mod 1.
# threadIdx.x 46 : mod 1.
# threadIdx.x 49 : mod 1.
# threadIdx.x 52 : mod 1.
# threadIdx.x 55 : mod 1.
# threadIdx.x 58 : mod 1.
# threadIdx.x 61 : mod 1.
# threadIdx.x 2 : mod 2.
# threadIdx.x 5 : mod 2.
# threadIdx.x 8 : mod 2.
# threadIdx.x 11 : mod 2.
# threadIdx.x 14 : mod 2.
# threadIdx.x 17 : mod 2.
# threadIdx.x 20 : mod 2.
# threadIdx.x 23 : mod 2.
# threadIdx.x 26 : mod 2.
# threadIdx.x 29 : mod 2.
# threadIdx.x 161 : mod 2.
# threadIdx.x 164 : mod 2.
# threadIdx.x 167 : mod 2.
# threadIdx.x 170 : mod 2.
# threadIdx.x 173 : mod 2.
# threadIdx.x 176 : mod 2.
# threadIdx.x 179 : mod 2.
# threadIdx.x 182 : mod 2.
# threadIdx.x 185 : mod 2.
# threadIdx.x 188 : mod 2.
# threadIdx.x 191 : mod 2.
# threadIdx.x 193 : mod 1.
# threadIdx.x 196 : mod 1.
# threadIdx.x 199 : mod 1.
# threadIdx.x 202 : mod 1.
# threadIdx.x 205 : mod 1.
# threadIdx.x 208 : mod 1.
# threadIdx.x 211 : mod 1.
# threadIdx.x 214 : mod 1.
# threadIdx.x 217 : mod 1.
# threadIdx.x 220 : mod 1.
# threadIdx.x 223 : mod 1.
# threadIdx.x 97 : mod 1.
# threadIdx.x 100 : mod 1.
# threadIdx.x 103 : mod 1.
# threadIdx.x 106 : mod 1.
# threadIdx.x 109 : mod 1.
# threadIdx.x 112 : mod 1.
# threadIdx.x 115 : mod 1.
# threadIdx.x 118 : mod 1.
# threadIdx.x 121 : mod 1.
# threadIdx.x 124 : mod 1.
# threadIdx.x 127 : mod 1.
# threadIdx.x 64 : mod 1.
# threadIdx.x 67 : mod 1.
# threadIdx.x 70 : mod 1.
# threadIdx.x 73 : mod 1.
# threadIdx.x 76 : mod 1.
# threadIdx.x 79 : mod 1.
# threadIdx.x 82 : mod 1.
# threadIdx.x 85 : mod 1.
# threadIdx.x 88 : mod 1.
# threadIdx.x 91 : mod 1.
# threadIdx.x 94 : mod 1.
# threadIdx.x 224 : mod 2.
# threadIdx.x 227 : mod 2.
# threadIdx.x 230 : mod 2.
# threadIdx.x 233 : mod 2.
# threadIdx.x 236 : mod 2.
# threadIdx.x 239 : mod 2.
# threadIdx.x 242 : mod 2.
# threadIdx.x 245 : mod 2.
# threadIdx.x 248 : mod 2.
# threadIdx.x 251 : mod 2.
# threadIdx.x 254 : mod 2.
# threadIdx.x 289 : mod 1.
# threadIdx.x 292 : mod 1.
# threadIdx.x 295 : mod 1.
# threadIdx.x 298 : mod 1.
# threadIdx.x 256 : mod 1.
# threadIdx.x 259 : mod 1.
# threadIdx.x 262 : mod 1.
# threadIdx.x 265 : mod 1.
# threadIdx.x 268 : mod 1.
# threadIdx.x 271 : mod 1.
# threadIdx.x 274 : mod 1.
# threadIdx.x 277 : mod 1.
# threadIdx.x 280 : mod 1.
# threadIdx.x 283 : mod 1.
# threadIdx.x 286 : mod 1.
# threadIdx.x 128 : mod 2.
# threadIdx.x 131 : mod 2.
# threadIdx.x 134 : mod 2.
# threadIdx.x 137 : mod 2.
# threadIdx.x 140 : mod 2.
# threadIdx.x 143 : mod 2.
# threadIdx.x 146 : mod 2.
# threadIdx.x 149 : mod 2.
# threadIdx.x 152 : mod 2.
# threadIdx.x 155 : mod 2.
# threadIdx.x 158 : mod 2.
# threadIdx.x 32 : mod 2.
# threadIdx.x 35 : mod 2.
# threadIdx.x 38 : mod 2.
# threadIdx.x 41 : mod 2.
# threadIdx.x 44 : mod 2.
# threadIdx.x 47 : mod 2.
# threadIdx.x 50 : mod 2.
# threadIdx.x 53 : mod 2.
# threadIdx.x 56 : mod 2.
# threadIdx.x 59 : mod 2.
# threadIdx.x 62 : mod 2.
# threadIdx.x 160 : mod 1.
# threadIdx.x 163 : mod 1.
# threadIdx.x 166 : mod 1.
# threadIdx.x 169 : mod 1.
# threadIdx.x 172 : mod 1.
# threadIdx.x 175 : mod 1.
# threadIdx.x 178 : mod 1.
# threadIdx.x 181 : mod 1.
# threadIdx.x 184 : mod 1.
# threadIdx.x 187 : mod 1.
# threadIdx.x 190 : mod 1.
# threadIdx.x 1 : mod 1.
# threadIdx.x 4 : mod 1.
# threadIdx.x 7 : mod 1.
# threadIdx.x 10 : mod 1.
# threadIdx.x 13 : mod 1.
# threadIdx.x 16 : mod 1.
# threadIdx.x 19 : mod 1.
# threadIdx.x 22 : mod 1.
# threadIdx.x 25 : mod 1.
# threadIdx.x 28 : mod 1.
# threadIdx.x 31 : mod 1.
